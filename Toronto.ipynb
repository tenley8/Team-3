# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
import sys
sys.path.append('../')
from config import db_password

# %%
db_string = f"postgres://postgres:{db_password}@module20covid.cgcfmenzscpu.us-east-2.rds.amazonaws.com:5432/postgres"
db = create_engine(db_string)

# %%
dftest = pd.read_sql(sql='Toronto_Cases', con=db)

# %%
dftest['neighbourhood_name'].unique()
# Out:
# array(['Malvern', 'Rouge', 'Centennial Scarborough', 'Highland Creek', '',
#        'West Hill', 'Guildwood', 'Morningside', 'Woburn',
#        'Scarborough Village', 'Eglinton East', 'Bendale',
#        'Clairlea-Birchmount', 'Kennedy Park', 'Ionview', 'Oakridge',
#        'Wexford/Maryvale', 'Cliffcrest', 'Birchcliffe-Cliffside',
#        'Dorset Park', 'Victoria Village', 'Agincourt South-Malvern West',
#        "L'Amoreaux", 'Agincourt North', "Tam O'Shanter-Sullivan",
#        'Milliken', 'Steeles', 'Hillcrest Village',
#        'Bayview Woods-Steeles', 'Henry Farm', 'Pleasant View',
#        'Don Valley Village', 'Bayview Village', 'Newtonbrook West',
#        'St.Andrew-Windfields', 'Bridle Path-Sunnybrook-York Mills',
#        'Newtonbrook East', 'Willowdale West', 'Willowdale East',
#        'Lansing-Westgate', 'Bay Street Corridor', 'Westminster-Branson',
#        'Parkwoods-Donalda', 'Banbury-Don Mills', 'Flemingdon Park',
#        "O'Connor-Parkview", 'Clanton Park', 'Bathurst Manor',
#        'York University Heights', 'Downsview-Roding-CFB',
#        'Glenfield-Jane Heights', 'Black Creek', 'Taylor-Massey',
#        'East End-Danforth', 'Woodbine Corridor', 'Danforth-East York',
#        'Woodbine-Lumsden', 'Old East York', 'Danforth', 'The Beaches',
#        'Leaside-Bennington', 'Thorncliffe Park', 'Blake-Jones',
#        'Greenwood-Coxwell', 'North Riverdale', 'Playter Estates-Danforth',
#        'Broadview North', 'South Riverdale', 'Lawrence Park South',
#        'Lawrence Park North', 'Bedford Park-Nortown', 'Rexdale-Kipling',
#        'Mount Pleasant West', 'Mount Pleasant East', 'Yonge-Eglinton',
#        'Rosedale-Moore Park', 'Casa Loma', 'Yonge-St.Clair',
#        'Forest Hill South', 'Church-Yonge Corridor',
#        'North St. James Town', 'Cabbagetown-South St. James Town',
#        'Moss Park', 'Regent Park', 'Waterfront Communities-The Island',
#        'Forest Hill North', 'Humewood-Cedarvale', 'Annex', 'Wychwood',
#        'University', 'Kensington-Chinatown', 'Niagara',
#        'Yorkdale-Glen Park', 'Englemount-Lawrence', 'Caledonia-Fairbank',
#        'Briar Hill - Belgravia', 'Elms-Old Rexdale',
#        'Beechborough-Greenbrook', 'Oakwood Village',
#        'Corso Italia-Davenport', 'Palmerston-Little Italy',
#        'Dovercourt-Wallace Emerson-Junction', 'Dufferin Grove',
#        'Trinity-Bellwoods', 'West Humber-Clairville', 'Little Portugal',
#        'South Parkdale', 'Roncesvalles', 'Maple Leaf',
#        'Brookhaven-Amesbury', 'Rustic', 'Mount Dennis',
#        'Keelesdale-Eglinton West', 'Weston-Pellam Park',
#        'Rockcliffe-Smythe', 'Junction Area', 'High Park North',
#        'High Park-Swansea', 'Runnymede-Bloor West Village',
#        'Lambton Baby Point', 'Mimico (includes Humber Bay Shores)',
#        'New Toronto', 'Long Branch', 'Alderwood', 'Stonegate-Queensway',
#        'Kingsway South', 'Islington-City Centre West',
#        'Edenbridge-Humber Valley', 'Princess-Rosethorn',
#        'Eringate-Centennial-West Deane', 'Humber Summit',
#        'Etobicoke West Mall', 'Markland Wood', 'Humbermede',
#        'Pelmo Park-Humberlea', 'Weston', 'Humber Heights-Westmount',
#        'Willowridge-Martingrove-Richview',
#        'Kingsview Village-The Westway', 'Thistletown-Beaumond Heights',
#        'Mount Olive-Silverstone-Jamestown'], dtype=object)

# %%
dftest
# Out:
#        index     id  outbreak_associated age_group neighbourhood_name  fsa  \
# 0          0  44294             Sporadic     50-59            Malvern  M1B
# 1          1  44295             Sporadic     20-29            Malvern  M1B
# 2          2  44296             Sporadic     60-69            Malvern  M1B
# 3          3  44297  Outbreak Associated     50-59              Rouge  M1B
# 4          4  44298             Sporadic     30-39              Rouge  M1B
# ...      ...    ...                  ...       ...                ...  ...
# 13677  14905  59199  Outbreak Associated     50-59
# 13678  14906  59200  Outbreak Associated     50-59
# 13679  14907  59201  Outbreak Associated     20-29
# 13680  14908  59202  Outbreak Associated     40-49
# 13681  14910  59204  Outbreak Associated     50-59
#
#                 infection_source classification episode_date reported_date  \
# 0                  Institutional      CONFIRMED   2020-03-25    2020-03-27
# 1                      Community      CONFIRMED   2020-03-20    2020-03-28
# 2                         Travel      CONFIRMED   2020-03-04    2020-03-08
# 3      N/A - Outbreak associated      CONFIRMED   2020-05-02    2020-05-04
# 4                  Close contact      CONFIRMED   2020-05-31    2020-06-06
# ...                          ...            ...          ...           ...
# 13677  N/A - Outbreak associated      CONFIRMED   2020-06-02    2020-06-03
# 13678  N/A - Outbreak associated      CONFIRMED   2020-06-11    2020-06-15
# 13679  N/A - Outbreak associated      CONFIRMED   2020-05-09    2020-05-23
# 13680  N/A - Outbreak associated      CONFIRMED   2020-06-18    2020-06-19
# 13681  N/A - Outbreak associated      CONFIRMED   2020-06-22    2020-06-23
#
#        gender   outcome currently_hospitalized currently_in_icu  \
# 0        MALE  RESOLVED                     No               No
# 1        MALE  RESOLVED                     No               No
# 2      FEMALE  RESOLVED                     No               No
# 3      FEMALE  RESOLVED                     No               No
# 4      FEMALE  RESOLVED                     No               No
# ...       ...       ...                    ...              ...
# 13677  FEMALE  RESOLVED                     No               No
# 13678  FEMALE  RESOLVED                     No               No
# 13679  FEMALE  RESOLVED                     No               No
# 13680  FEMALE  RESOLVED                     No               No
# 13681  FEMALE  RESOLVED                     No               No
#
#       currently_intubated ever_hospitalized ever_in_icu ever_intubated
# 0                      No                No          No             No
# 1                      No               Yes          No             No
# 2                      No               Yes         Yes            Yes
# 3                      No                No          No             No
# 4                      No                No          No             No
# ...                   ...               ...         ...            ...
# 13677                  No                No          No             No
# 13678                  No                No          No             No
# 13679                  No                No          No             No
# 13680                  No                No          No             No
# 13681                  No               Yes          No             No
#
# [13682 rows x 18 columns]
