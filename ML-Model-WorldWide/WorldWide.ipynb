# %%
import pandas as pd

# %%
# Import our input dataset
df = pd.read_csv('Resources/CovidWorldWide.csv')
df.tail()
# Out:
#       ISO_Code continent   Country        Date  TotalCase  NewCase  \
# 28339      ZWE    Africa  Zimbabwe  2020-07-03      617.0     12.0
# 28340      ZWE    Africa  Zimbabwe  2020-07-04      625.0      8.0
# 28341      ZWE    Africa  Zimbabwe  2020-07-05      698.0     73.0
# 28342      ZWE    Africa  Zimbabwe  2020-07-06      716.0     18.0
# 28343      ZWE    Africa  Zimbabwe  2020-07-07      734.0     18.0
#
#        TotalDeath  NewDeath  TotalTest  NewTest  ... Aged_65_Older  \
# 28339         7.0       0.0    32112.0    499.0  ...         2.822
# 28340         7.0       0.0    32845.0    733.0  ...         2.822
# 28341         8.0       1.0    33256.0    411.0  ...         2.822
# 28342         8.0       0.0        NaN      NaN  ...         2.822
# 28343         9.0       1.0        NaN      NaN  ...         2.822
#
#        Aged_70_Older GDPperCapita  ExtremePovertyRate  DiabetesRate  \
# 28339          1.882     1899.775                21.4          1.82
# ...

# %%
df[df['Date'] == '2020-07-07']
# Out:
#       ISO_Code continent         Country        Date  TotalCase  NewCase  \
# 179        AFG      Asia     Afghanistan  2020-07-07    33384.0    433.0
# 300        ALB    Europe         Albania  2020-07-07     2964.0     71.0
# 485        DZA    Africa         Algeria  2020-07-07    16404.0    463.0
# 601        AND    Europe         Andorra  2020-07-07      855.0      0.0
# 709        AGO    Africa          Angola  2020-07-07      353.0      7.0
# ...        ...       ...             ...         ...        ...      ...
# 27961      VNM      Asia         Vietnam  2020-07-07      369.0     14.0
# 28034      ESH    Africa  Western Sahara  2020-07-07      519.0      0.0
# 28123      YEM      Asia           Yemen  2020-07-07     1290.0     25.0
# 28234      ZMB    Africa          Zambia  2020-07-07     1632.0      0.0
# 28343      ZWE    Africa        Zimbabwe  2020-07-07      734.0     18.0
#
#        TotalDeath  NewDeath  TotalTest  NewTest  ... Aged_65_Older  \
# ...

# %%
df.dtypes
# Out:
# ISO_Code                   object
# continent                  object
# Country                    object
# Date                       object
# TotalCase                 float64
# NewCase                   float64
# TotalDeath                float64
# NewDeath                  float64
# TotalTest                 float64
# NewTest                   float64
# TestUnits                  object
# StringencyIndex           float64
# Date_FirstCase             object
# DateSinceFirstCase          int64
# Population                  int64
# Population_Density        float64
# AverageAge                float64
# Aged_65_Older             float64
# Aged_70_Older             float64
# GDPperCapita              float64
# ExtremePovertyRate        float64
# DiabetesRate              float64
# FemaleSmokers             float64
# MaleSmokers               float64
# HandwashingFacilities     float64
# HospitalBedperThousand    float64
# LifeExpectancy            float64
# dtype: object

# %% [markdown]
# ## Steps required Pre-Processing
# * Take the data from the latest date (= Groupby)
# * Drop ISO_Code, continent, Date, Country, NewCase, NewDeath
# * Drop Null Values (Could we try the model without dropping null values?)

# %%
df2 = df[['TotalCase','TotalDeath','TotalTest', 'NewTest','TestUnits','StringencyIndex','Date_FirstCase','DateSinceFirstCase','Population','Population_Density','AverageAge','Aged_65_Older','Aged_70_Older','GDPperCapita','ExtremePovertyRate','DiabetesRate','FemaleSmokers','MaleSmokers','HandwashingFacilities','HospitalBedperThousand','LifeExpectancy']]
df2.head()
# Out:
#    TotalCase  TotalDeath  TotalTest  NewTest TestUnits  StringencyIndex  \
# 0        0.0         0.0        NaN      NaN       NaN              NaN
# 1        0.0         0.0        NaN      NaN       NaN              0.0
# 2        0.0         0.0        NaN      NaN       NaN              0.0
# 3        0.0         0.0        NaN      NaN       NaN              0.0
# 4        0.0         0.0        NaN      NaN       NaN              0.0
#
#   Date_FirstCase  DateSinceFirstCase  Population  Population_Density  ...  \
# 0     2020-02-25                   0    38928341              54.422  ...
# 1     2020-02-25                   0    38928341              54.422  ...
# 2     2020-02-25                   0    38928341              54.422  ...
# 3     2020-02-25                   0    38928341              54.422  ...
# 4     2020-02-25                   0    38928341              54.422  ...
#
#    Aged_65_Older  Aged_70_Older  GDPperCapita  ExtremePovertyRate  \
# ...

# %%
# Return columns with Null values 
for column in df2.columns:
    print(f"Column {column} has {df2[column].isnull().sum()} null values")
# Out:
# Column TotalCase has 274 null values
# Column TotalDeath has 274 null values
# Column TotalTest has 19639 null values
# Column NewTest has 20039 null values
# Column TestUnits has 18242 null values
# Column StringencyIndex has 5196 null values
# Column Date_FirstCase has 0 null values
# Column DateSinceFirstCase has 0 null values
# Column Population has 0 null values
# Column Population_Density has 1200 null values
# Column AverageAge has 2635 null values
# Column Aged_65_Older has 3004 null values
# Column Aged_70_Older has 2768 null values
# Column GDPperCapita has 3050 null values
# Column ExtremePovertyRate has 11524 null values
# Column DiabetesRate has 1758 null values
# Column FemaleSmokers has 7820 null values
# Column MaleSmokers has 8062 null values
# Column HandwashingFacilities has 16794 null values
# Column HospitalBedperThousand has 4872 null values
# Column LifeExpectancy has 220 null values

# %%
# Retrun df duplicates
print(f"Duplicate entries: {df2.duplicated().sum()}")
# Out:
# Duplicate entries: 2600

# %%
# Display Dataframe
df2.head()
# Out:
#    TotalCase  TotalDeath  TotalTest  NewTest TestUnits  StringencyIndex  \
# 0        0.0         0.0        NaN      NaN       NaN              NaN
# 1        0.0         0.0        NaN      NaN       NaN              0.0
# 2        0.0         0.0        NaN      NaN       NaN              0.0
# 3        0.0         0.0        NaN      NaN       NaN              0.0
# 4        0.0         0.0        NaN      NaN       NaN              0.0
#
#   Date_FirstCase  DateSinceFirstCase  Population  Population_Density  ...  \
# 0     2020-02-25                   0    38928341              54.422  ...
# 1     2020-02-25                   0    38928341              54.422  ...
# 2     2020-02-25                   0    38928341              54.422  ...
# 3     2020-02-25                   0    38928341              54.422  ...
# 4     2020-02-25                   0    38928341              54.422  ...
#
#    Aged_65_Older  Aged_70_Older  GDPperCapita  ExtremePovertyRate  \
# ...

# %%
# Categorical variable list
df2_cat = df2.dtypes[df.dtypes == "float64"].index.tolist()
df2_cat
# Out:
# ['TotalCase',
#  'TotalDeath',
#  'TotalTest',
#  'NewTest',
#  'StringencyIndex',
#  'Population_Density',
#  'AverageAge',
#  'Aged_65_Older',
#  'Aged_70_Older',
#  'GDPperCapita',
#  'ExtremePovertyRate',
#  'DiabetesRate',
#  'FemaleSmokers',
#  'MaleSmokers',
#  'HandwashingFacilities',
#  'HospitalBedperThousand',
#  'LifeExpectancy']

# %%
# Unique numbers
df2[df2_cat].nunique()
# Out:
# TotalCase                 8777
# TotalDeath                2944
# TotalTest                 8362
# NewTest                   5625
# StringencyIndex            156
# Population_Density         198
# AverageAge                 132
# Aged_65_Older              182
# Aged_70_Older              181
# GDPperCapita               182
# ExtremePovertyRate          72
# DiabetesRate               140
# FemaleSmokers              106
# MaleSmokers                121
# HandwashingFacilities       91
# HospitalBedperThousand      99
# LifeExpectancy             197
# dtype: int64
